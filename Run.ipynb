# %%
# Start from root
# %cd /

# Create and navigate to workspace
# !mkdir -p /workspace
# %cd /workspace

# Remove old repo if exists
# !rm -rf Qwen3-8B-Danish-Inst

# Clone fresh
# !git clone https://github.com/anderskruse/Qwen3-8B-Danish-Inst.git
# %cd Qwen3-8B-Danish-Inst

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
!~/.local/bin/uv venv .venv --clear
!~/.local/bin/uv pip install -e . --python .venv/bin/python
# Out:
# downloading uv 0.9.27 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /root/.local/bin
#   uv
#   uvx
# everything's installed!
# WARN: The following commands are shadowed by other commands in your PATH: uv uvx
# Using CPython 3.12.3 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Resolved 88 packages in 624ms
# Prepared 1 package in 572ms
# Installed 88 packages in 360ms
#  + accelerate==1.12.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + anyio==4.12.1
#  + attrs==25.4.0
#  + bitsandbytes==0.49.1
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + cuda-bindings==12.9.4
#  + cuda-pathfinder==1.3.3
#  + cut-cross-entropy==25.1.1
#  + datasets==4.3.0
#  + dill==0.4.0
#  + docstring-parser==0.17.0
#  + filelock==3.20.3
#  + frozenlist==1.8.0
#  + fsspec==2025.9.0
#  + h11==0.16.0
#  + hf-transfer==0.1.9
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
# ...

# %%
from huggingface_hub import login
login(token="[]")

# %%
from huggingface_hub import whoami
whoami()
# Out:
# {'type': 'user',
#  'id': '68dc10a23a2b55c87699aa21',
#  'name': 'AndersMK',
#  'fullname': 'K',
#  'email': 'amkruse@gmail.com',
#  'emailVerified': True,
#  'canPay': False,
#  'billingMode': 'prepaid',
#  'periodEnd': 1769904000,
#  'isPro': False,
#  'avatarUrl': '/avatars/58a26212dbf6f460725db4cc6ac90186.svg',
#  'orgs': [],
#  'auth': {'type': 'access_token',
#   'accessToken': {'displayName': 'hf_code2',
#    'role': 'write',
#    'createdAt': '2026-01-27T20:02:26.110Z'}}}

# %%
# !.venv/bin/python -c "import torch; print(f'PyTorch: {torch.__version__}')"
# Out:
# PyTorch: 2.10.0+cu128

# %%
# Train with defaults (Mistral-Nemo-12B + skolegpt-instruct)
# !.venv/bin/python train.py

# Or override model, dataset, and hyperparameters:
# !.venv/bin/python train.py --model unsloth/Mistral-Nemo-Instruct-2407 --dataset kobprof/skolegpt-instruct --epochs 3 --lr 5e-5

# %%
# Evaluate the fine-tuned model
# !.venv/bin/python evaluate.py --model ./outputs/merged_model

# %%
# Export to GGUF (for llama.cpp, Ollama, LM Studio, etc.)
# !.venv/bin/python export_gguf.py --quant q4_k_m

# %%
# Upload to Hugging Face
# !.venv/bin/python upload_model.py --repo AndersMK/Mistral-Nemo-12B-Danish-Instruct --model-name unsloth/Mistral-Nemo-Instruct-2407
